# %%
# !pip install gimme-aws-creds
# Out:
# ...
#      --------------------------------------- 57.1/57.1 kB 96.5 kB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\ananya\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\ananya\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\ananya\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\ananya\anaconda3\lib\site-packages)
#   ERROR: Error [WinError 225] Operation did not complete successfully because the file contains a virus or potentially unwanted software while executing command python setup.py egg_info
# ERROR: Could not install packages due to an OSError: [WinError 225] Operation did not complete successfully because the file contains a virus or potentially unwanted software
#
# ...

# %%
# !pip install gradio
# !pip install fastai
# Out:
# ...
#   Using cached gradio-3.47.1-py3-none-any.whl (20.3 MB)
# ...
#   Using cached huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
# ...
#   Using cached altair-5.1.2-py3-none-any.whl (516 kB)
# ...
#   Using cached pydantic-2.4.2-py3-none-any.whl (395 kB)
# ...
#   Using cached uvicorn-0.23.2-py3-none-any.whl (59 kB)
# ...
#   Using cached websockets-11.0.3-cp39-cp39-win_amd64.whl (124 kB)
# ...
#   Using cached gradio_client-0.6.0-py3-none-any.whl (298 kB)
# ...
#   Using cached aiofiles-23.2.1-py3-none-any.whl (15 kB)
# ...
#      --------------------------------------- 75.7/75.7 kB 62.6 kB/s eta 0:00:00
# ...
#   Using cached fastapi-0.103.2-py3-none-any.whl (66 kB)
# ...
#   Using cached python_multipart-0.0.6-py3-none-any.whl (45 kB)
# ...
#   Using cached semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# ...
#   Using cached ffmpy-0.3.1.tar.gz (5.5 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# ...

# %%
from fastai.vision.all import *
import gradio as gr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20260\2197721857.py in <module>
#       1 from fastai.vision.all import *
# ----> 2 import gradio as gr
#
# ModuleNotFoundError: No module named 'gradio'

# %%
im = PILImage.create('test.png')
im

# %%
import pathlib
temp = pathlib.PosixPath
pathlib.PosixPath = pathlib.WindowsPath

learn = load_learner('models/140k-real-fake-face.pkl')
